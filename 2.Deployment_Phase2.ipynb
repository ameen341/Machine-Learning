# %%
import pickle
# checking the model in separate file

# %%
loaded_model = pickle.load(open("final_model_linear.sav", 'rb'))
result = loaded_model.predict([[int(input())]])
# deployment file and model has to be in same location to load and access the model
# Out:
#  15
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[167181.3106341]])
